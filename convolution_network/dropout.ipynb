# %%
from tensorflow import keras

# %%
model = keras.Sequential([keras.layers.Conv2D(16, (3, 3), activation=tf.nn.tanh, input_shape=(150, 150, 3)),
                         keras.layers.MaxPooling2D(2, 2),
                         keras.layers.Conv2D(32, (3, 3), activation=tf.nn.tanh),
                         keras.layers.MaxPooling2D(2, 2),
                         keras.layers.Conv2D(64, (3, 3), activation=tf.nn.tanh),
                         keras.layers.MaxPooling2D(2, 2),
                         keras.layers.Flatten(),
                         keras.layers.Dense(512, activation=tf.nn.tanh),
                         keras.Dropout(0.2)
                         keras.layers.Dense(1, activation=tf.nn.sigmoid)])

# %%
y = 10
x = keras.layers.Flatten()(y)
x = keras.layers.Dense(512, activation=tf.nn.tanh)(x)
x = keras.Dropout(0.2)(x)
x = keras.layers.Dense(1, activation=tf.nn.sigmoid)(x)
