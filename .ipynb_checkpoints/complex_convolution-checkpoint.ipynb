# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
import tensorflow as tf

# %% [markdown]
# train directory have to be a directory having a sub-directory. And we need to resize the image. And these full code will be same for validation. we use validation to increase test accuracy.

# %%
train_datageneration = ImageDataGenerator(rescale=1./255)
train_generator = train_datageneration.flow_from_directory(train_dir,
                                                          terget_size=(300, 300),
                                                          batch_size=128, 
                                                          class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-56869ad5ea90> in <module>
#       1 train_datageneration = ImageDataGenerator(rescale=1./255)
# ----> 2 train_generator = train_datageneration.flow_from_directory(train_dir,
#       3                                                           terget_size=(300, 300),
#       4                                                           batch_size=128,
#       5                                                           class_mode='binary')
#
# NameError: name 'train_dir' is not defined

# %%
model = keras.Sequential([keras.layers.Conv2D(16, (3, 3), activation=tf.nn.tanh, input_shape=(300, 300, 3)),
                         keras.layers.MaxPooling2D(2, 2),
                         keras.layers.Conv2D(32, (3, 3), activation=tf.nn.tanh),
                         keras.layers.MaxPooling2D(2, 2),
                         keras.layers.Conv2D(64, (3, 3), activation=tf.nn.tanh),
                         keras.layers.MaxPooling2D(2, 2),
                         keras.layers.Flatten(),
                         keras.layers.Dense(512, activation=tf.nn.tanh),
                         keras.layers.Dense(1, activation=tf.nn.sigmoid)])

# %%
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.001),
             loss='binary_crossentropy',
             metrics=['acc'])

# %%
model.fit_generator(train_generator,
                   steps_per_epoch=8,
                   epochs=15,
                   #validation_data=validation_generator. # when validation is added
                   #validation_steps=8,
                   verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7e06d2adffd6> in <module>
# ----> 1 model.fit_generator(train_generator,
#       2                    steps_per_epoch=8,
#       3                    epochs=15,
#       4                    #validation_data=validation_generator. # when validation is added
#       5                    #validation_steps=8,
#
# NameError: name 'train_generator' is not defined
